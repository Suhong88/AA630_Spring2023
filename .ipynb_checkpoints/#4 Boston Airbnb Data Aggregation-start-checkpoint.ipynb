# %% [markdown]
# # Boston Airbnb Open Data
#
# This data set was obtained from [Kaggle](https://www.kaggle.com/datasets/airbnb/boston).
#
# this dataset describes the listing activity of homestays in Boston, MA.
#
# The following Airbnb activity is included in this Boston dataset:
#
#  - Listings, including full descriptions and average review score
#  - Reviews, including unique id for each reviewer and detailed comments
#  - Calendar, including listing id and the price and availability for that day

# %% [markdown]
# # Boston Airbnb Data Aggregation

# %% [markdown]
# ## Import Functions and load data

# %% [markdown]
# ### Import cleaned listing data

# %%
import pandas as pd
import numpy as np

## Load the data for further analysis

#listing=pd.read_csv('airbnb_boston/listings_cleaned.csv')

listing=pd.read_csv('https://raw.githubusercontent.com/Suhong88/AA630_Spring2023/main/listings_cleaned.csv')

listing.head()
# Out:
#          id                            listing_url  \
# 0  12147973  https://www.airbnb.com/rooms/12147973
# 1   3075044   https://www.airbnb.com/rooms/3075044
# 2      6976      https://www.airbnb.com/rooms/6976
# 3   1436513   https://www.airbnb.com/rooms/1436513
# 4   7651065   https://www.airbnb.com/rooms/7651065
#
#                                             name neighbourhood    city state  \
# 0                     Sunny Bungalow in the City    Roslindale  Boston    MA
# 1              Charming room in pet friendly apt    Roslindale  Boston    MA
# 2               Mexican Folk Art Haven in Boston    Roslindale  Boston    MA
# 3  Spacious Sunny Bedroom Suite in Historic Home    Roslindale  Boston    MA
# 4                            Come Home to Boston    Roslindale  Boston    MA
#
#   zipcode   latitude  longitude host_name  ...  bed_type  \
# 0   02131  42.282619 -71.133068  Virginia  ...  Real Bed
# 1   02131  42.286241 -71.134374    Andrea  ...  Real Bed
# 2   02131  42.292438 -71.135765      Phil  ...  Real Bed
# 3     NaN  42.281106 -71.121021    Meghna  ...  Real Bed
# 4   02131  42.284512 -71.136258     Linda  ...  Real Bed
#
#                                            amenities  price  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...  250.0
# 1  {TV,Internet,"Wireless Internet","Air Conditio...   65.0
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...   65.0
# 3  {TV,Internet,"Wireless Internet","Air Conditio...   75.0
# 4  {Internet,"Wireless Internet","Air Conditionin...   79.0
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0             91.916667                9.431571                   9.258041
# 1             94.000000               10.000000                   9.000000
# 2             98.000000               10.000000                   9.000000
# 3            100.000000               10.000000                  10.000000
# 4             99.000000               10.000000                  10.000000
#
#   review_scores_checkin review_scores_communication  review_scores_location  \
# 0              9.646293                    9.646549                9.414043
# 1             10.000000                   10.000000                9.000000
# 2             10.000000                   10.000000                9.000000
# 3             10.000000                   10.000000               10.000000
# 4             10.000000                   10.000000                9.000000
#
#    review_scores_value
# 0             9.168234
# 1             9.000000
# 2            10.000000
# 3            10.000000
# 4            10.000000
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Import reviews data
#
# - each reviewer can write multiple reviews
# - listing and reviews are joined by id in the listing table, and listing_id in review table.

# %%
# reviews=pd.read_csv('airbnb_boston/reviews.csv')

reviews=pd.read_csv('https://raw.githubusercontent.com/Suhong88/AA630_Spring2023/main/airbnb_boston/reviews.csv')

reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
reviews.dtypes
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
# covert listing_id from int to object

reviews['listing_id']=reviews['listing_id'].astype('object')

# covert date from object to date

reviews['date']=pd.to_datetime(reviews.date)

# %%
reviews.dtypes
# Out:
# listing_id               object
# id                        int64
# date             datetime64[ns]
# reviewer_id               int64
# reviewer_name            object
# comments                 object
# dtype: object

# %%
# drop id from reviews table

reviews1=reviews.drop(['id'], axis=1)

# %%
reviews1.head()
# Out:
#   listing_id       date  reviewer_id reviewer_name  \
# 0    1178162 2013-05-21      4298113       Olivier
# 1    1178162 2013-05-29      6452964     Charlotte
# 2    1178162 2013-06-06      6449554     Sebastian
# 3    1178162 2013-06-15      2215611        Marine
# 4    1178162 2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %% [markdown]
# # Merging Dataframe
#
# ## Merge data from listings and reviews

# %%
# inner join gives us all listing appear in both tables

combined_inner=listing.merge(reviews1, left_on='id', right_on='listing_id', how='inner')

# left join gives us all listing appear in both tables and also listings that do not have a review yet

combined_left=listing.merge(reviews1, left_on='id', right_on='listing_id', how='left')

# right join gives us all listing appear in both tables and also reviews that have no matching listing id in the listing table (bad data)

combined_right=listing.merge(reviews1, left_on='id', right_on='listing_id', how='right')

# outer join gives us all listings appear in both tables and in either of the left/right tables

combined_outer=listing.merge(reviews1, left_on='id', right_on='listing_id', how='outer')

# %%
print(combined_inner.shape, combined_left.shape,combined_right.shape,combined_outer.shape)
# Out:
# (68260, 31) (69007, 31) (68275, 31) (69022, 31)

# %%
combined_inner.head()
# Out:
#         id                           listing_url  \
# 0  3075044  https://www.airbnb.com/rooms/3075044
# 1  3075044  https://www.airbnb.com/rooms/3075044
# 2  3075044  https://www.airbnb.com/rooms/3075044
# 3  3075044  https://www.airbnb.com/rooms/3075044
# 4  3075044  https://www.airbnb.com/rooms/3075044
#
#                                 name neighbourhood    city state zipcode  \
# 0  Charming room in pet friendly apt    Roslindale  Boston    MA   02131
# 1  Charming room in pet friendly apt    Roslindale  Boston    MA   02131
# 2  Charming room in pet friendly apt    Roslindale  Boston    MA   02131
# 3  Charming room in pet friendly apt    Roslindale  Boston    MA   02131
# 4  Charming room in pet friendly apt    Roslindale  Boston    MA   02131
#
#     latitude  longitude host_name  ... review_scores_cleanliness  \
# 0  42.286241 -71.134374    Andrea  ...                       9.0
# 1  42.286241 -71.134374    Andrea  ...                       9.0
# 2  42.286241 -71.134374    Andrea  ...                       9.0
# 3  42.286241 -71.134374    Andrea  ...                       9.0
# 4  42.286241 -71.134374    Andrea  ...                       9.0
#
#   review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                  10.0                         10.0                     9.0
# 1                  10.0                         10.0                     9.0
# 2                  10.0                         10.0                     9.0
# 3                  10.0                         10.0                     9.0
# 4                  10.0                         10.0                     9.0
#
#    review_scores_value  listing_id       date reviewer_id  reviewer_name  \
# 0                  9.0     3075044 2014-06-01     9645972        Dmitrii
# 1                  9.0     3075044 2014-06-06    12020681          Paola
# 2                  9.0     3075044 2014-06-30     8165047         Jaydee
# 3                  9.0     3075044 2014-09-18    21319433        Anthony
# 4                  9.0     3075044 2014-09-27    21706950          Xinny
#
#                                             comments
# 0  Andrea is a great host. Neighborhood is wonder...
# 1  We had a great time at Andrea's place. He is v...
# 2  Adrea was very welcoming and flexible to our n...
# 3  Andrea made us feel welcome because he made th...
# 4  Me and my friend were so happy about Andrea's ...
#
# [5 rows x 31 columns]

# %% [markdown]
# # Binning
#
# ## Classify price into different range. Create 4 bins for price

# %% [markdown]
# # Summarizing Dataframes

# %%
listing.columns
# Out:
# Index(['id', 'listing_url', 'name', 'neighbourhood', 'city', 'state',
#        'zipcode', 'latitude', 'longitude', 'host_name', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'bed_type', 'amenities', 'price', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'price_level'],
#       dtype='object')

# %%
# display max, min, average price for all listings

# %%
# display max, min, average price and review_score_rating, and average number of bedrooms for all listings

# %% [markdown]
# # Using groupby

# %% [markdown]
# ## display count, mean, max, min price for all listing by neighborhood. Limit to top 5 neighbourhood based on number of listings

# %%
# show mean for all numerical columns

# %%
# only show the mean for the price

# %%
# display count, mean, min and max price by nieghbourhood

# %%
# limit to top 5 neighbourhood based on number of listing

# %%
# sort the value by count

# %% [markdown]
# ## Explore amenities
#
# - what are the most popular amenities?

# %%
listing['amenities']
# Out:
# 0       {TV,"Wireless Internet",Kitchen,"Free Parking ...
# 1       {TV,Internet,"Wireless Internet","Air Conditio...
# 2       {TV,"Cable TV","Wireless Internet","Air Condit...
# 3       {TV,Internet,"Wireless Internet","Air Conditio...
# 4       {Internet,"Wireless Internet","Air Conditionin...
#                               ...
# 3568    {Internet,"Wireless Internet","Air Conditionin...
# 3569    {TV,Internet,"Wireless Internet","Air Conditio...
# 3570    {"translation missing: en.hosting_amenity_49",...
# 3571    {Kitchen,Gym,"Family/Kid Friendly",Washer,Drye...
# 3572    {"Wireless Internet",Kitchen,Essentials,"trans...
# Name: amenities, Length: 3573, dtype: object

# %%
# increase width of pandas column to see the full content of amenities

pd.set_option('display.max_colwidth', 100)

listing['amenities']
# Out:
# 0       {TV,"Wireless Internet",Kitchen,"Free Parking on Premises","Pets live on this property",Dog(s),H...
# 1       {TV,Internet,"Wireless Internet","Air Conditioning",Kitchen,"Pets Allowed","Pets live on this pr...
# 2       {TV,"Cable TV","Wireless Internet","Air Conditioning",Kitchen,"Free Parking on Premises",Heating...
# 3       {TV,Internet,"Wireless Internet","Air Conditioning",Kitchen,"Free Parking on Premises",Gym,Break...
# 4       {Internet,"Wireless Internet","Air Conditioning",Kitchen,Breakfast,Heating,"Smoke Detector","Car...
#                                                        ...
# 3568    {Internet,"Wireless Internet","Air Conditioning",Kitchen,"Free Parking on Premises",Heating,"Fam...
# 3569    {TV,Internet,"Wireless Internet","Air Conditioning",Kitchen,"Free Parking on Premises","Smoking ...
# 3570            {"translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}
# 3571    {Kitchen,Gym,"Family/Kid Friendly",Washer,Dryer,Essentials,Hangers,"translation missing: en.host...
# 3572    {"Wireless Internet",Kitchen,Essentials,"translation missing: en.hosting_amenity_49","translatio...
# Name: amenities, Length: 3573, dtype: object

# %%
# show top 10 amenities

# %%
# for the top 10 amenities, what are the average price by amenities.

# %%
# for the top 10 amenities, what are the average price by amenities by neighbourhood. Limit to top 5 neighbourhood

# %% [markdown]
# # Pivot table and crosstabs

# %%
# for the top 10 amenities, what are the average price by amenities by neighbourhood. Limit to top 5 neighbourhood

condition=(listing.amenities2.isin(top10_amenities)) & (listing.neighbourhood.isin(top5))

listing2=listing[condition]

listing2.pivot_table(
    index='neighbourhood',
    columns='amenities2',
    values='price',
    aggfunc='mean'
).reset_index()
# Out:
# amenities2  neighbourhood  "Air Conditioning"  "Carbon Monoxide Detector"  \
# 0                Back Bay          214.125000                  244.076923
# 1              Dorchester           88.000000                   82.714286
# 2                  Fenway          181.875000                  251.571429
# 3           Jamaica Plain          152.764706                  123.333333
# 4               South End          224.692308                  221.066667
#
# amenities2  "Smoke Detector"  "Wireless Internet"       Dryer  Essentials  \
# 0                 237.933333           249.928571  244.933333  288.384615
# 1                  96.000000           109.133333   73.416667   85.363636
# 2                 231.500000           159.928571  212.777778  216.800000
# 3                 148.100000           109.619048  120.153846  154.250000
# 4                 211.111111           219.611111  173.647059  147.800000
#
# amenities2     Heating     Kitchen      Washer         {TV
# 0           243.105263  228.368421  250.812500  219.250000
# 1           101.714286   76.266667   96.692308   76.900000
# 2           220.266667  184.785714  201.400000  168.636364
# 3           138.047619  112.833333  175.230769  163.000000
# 4           196.904762  172.631579  214.647059  237.181818

# %%
# modify the above query to show the average price by amenities by property type for each neighbourhood

condition=(listing.amenities2.isin(top10_amenities)) & (listing.neighbourhood.isin(top5))

listing2=listing[condition]

listing2.pivot_table(
    index=['neighbourhood','property_type'],
    columns='amenities3',
    values='price',
    aggfunc='mean'
).reset_index()
# Out:
# amenities3  neighbourhood    property_type  Air_Conditioning  \
# 0                Back Bay        Apartment        244.000000
# 1                Back Bay      Condominium         89.000000
# 2                Back Bay             Loft        160.000000
# 3                Back Bay            Other               NaN
# 4              Dorchester        Apartment         94.666667
# 5              Dorchester  Bed & Breakfast               NaN
# 6              Dorchester      Condominium         80.000000
# 7              Dorchester            House         77.333333
# 8              Dorchester        Townhouse               NaN
# 9                  Fenway        Apartment        181.875000
# 10                 Fenway  Bed & Breakfast               NaN
# 11                 Fenway      Condominium               NaN
# 12                 Fenway            House               NaN
# 13          Jamaica Plain        Apartment        156.083333
# 14          Jamaica Plain  Bed & Breakfast               NaN
# 15          Jamaica Plain      Condominium               NaN
# 16          Jamaica Plain            House        159.750000
# 17          Jamaica Plain             Loft               NaN
# 18          Jamaica Plain        Townhouse         85.000000
# 19              South End        Apartment        187.625000
# 20              South End  Bed & Breakfast        325.000000
# 21              South End      Condominium        115.000000
# 22              South End             Dorm               NaN
# 23              South End            House        410.000000
# 24              South End             Loft               NaN
# 25              South End            Other               NaN
# 26              South End        Townhouse        160.000000
#
# amenities3  Carbon_Monoxide_Detector       Dryer  Essentials     Heating  \
# 0                         247.750000  241.785714  262.272727  268.285714
# 1                         200.000000  289.000000  432.000000  172.000000
# 2                                NaN         NaN         NaN  175.000000
# 3                                NaN         NaN         NaN         NaN
# 4                          78.700000   84.333333   61.333333   81.375000
# 5                                NaN         NaN         NaN   89.500000
# 6                                NaN         NaN  189.000000         NaN
# 7                          92.750000   64.000000   95.500000  148.500000
# 8                                NaN   55.000000         NaN         NaN
# 9                         256.307692  212.777778  216.800000  235.166667
# 10                               NaN         NaN         NaN         NaN
# 11                               NaN         NaN         NaN  166.500000
# 12                        190.000000         NaN         NaN  149.000000
# 13                        145.500000  109.333333  117.250000  104.600000
# 14                         80.000000   70.000000         NaN         NaN
# 15                               NaN  224.000000         NaN         NaN
# 16                        106.000000   60.000000  209.285714  158.500000
# 17                               NaN         NaN         NaN         NaN
# 18                         75.000000         NaN   65.000000   78.500000
# 19                        220.500000  181.133333  143.076923  181.166667
# 20                               NaN         NaN  168.000000  299.000000
# 21                        350.000000  110.000000  189.000000         NaN
# 22                               NaN         NaN         NaN   75.000000
# 23                        220.000000  125.000000         NaN         NaN
# 24                        100.000000         NaN         NaN         NaN
# 25                               NaN         NaN         NaN  500.000000
# 26                               NaN         NaN         NaN         NaN
#
# amenities3     Kitchen  Smoke_Detector          TV      Washer  \
# 0           228.588235      237.933333  219.250000  244.200000
# 1           235.000000             NaN         NaN  350.000000
# 2                  NaN             NaN         NaN         NaN
# 3           218.000000             NaN         NaN         NaN
# 4            78.625000       73.500000   73.333333  114.857143
# 5                  NaN             NaN         NaN         NaN
# 6            61.333333      155.000000         NaN         NaN
# 7            90.666667       70.750000   85.333333   75.500000
# 8            59.000000             NaN   73.000000         NaN
# 9           184.785714      223.600000  168.000000  201.400000
# 10                 NaN             NaN  175.000000         NaN
# 11                 NaN      350.000000         NaN         NaN
# 12                 NaN             NaN         NaN         NaN
# 13           84.900000      129.200000  143.818182  181.750000
# 14                 NaN      119.000000         NaN         NaN
# 15          172.333333      192.500000  145.000000  122.000000
# 16          111.250000      260.000000  480.000000  193.333333
# 17          220.000000             NaN         NaN         NaN
# 18                 NaN             NaN   75.000000         NaN
# 19          178.733333      199.800000  208.777778  208.000000
# 20                 NaN             NaN         NaN         NaN
# 21          250.000000      133.000000  600.000000  264.500000
# 22                 NaN             NaN         NaN         NaN
# 23          135.000000             NaN  130.000000         NaN
# 24           69.000000             NaN         NaN         NaN
# 25                 NaN      500.000000         NaN         NaN
# 26          145.000000      170.000000         NaN         NaN
#
# amenities3  Wireless_Internet
# 0                  266.076923
# 1                         NaN
# 2                         NaN
# 3                   40.000000
# 4                  152.857143
# 5                  100.000000
# 6                         NaN
# 7                   66.714286
# 8                         NaN
# 9                  150.769231
# 10                        NaN
# 11                 279.000000
# 12                        NaN
# 13                 126.900000
# 14                  60.000000
# 15                        NaN
# 16                  95.000000
# 17                 130.000000
# 18                  89.000000
# 19                 197.428571
# 20                        NaN
# 21                 282.000000
# 22                        NaN
# 23                        NaN
# 24                  50.000000
# 25                        NaN
# 26                 575.000000

# %% [markdown]
# We can use the pd.crosstab() function to create a frequency table. For examplem, we want to see number of listing by neighbourhood and property type

# %%
pd.crosstab(
    index=listing2.neighbourhood,
    columns=listing2.property_type,
    colnames=['property type'] # name the columns index
)
# Out:
# property type  Apartment  Bed & Breakfast  Condominium  Dorm  House  Loft  \
# neighbourhood
# Back Bay             129                0           11     0      0     2
# Dorchester            70                3            9     0     43     0
# Fenway               119                1            4     0      2     0
# Jamaica Plain         98                5           10     0     48     2
# South End            134                3           11     1      6     3
#
# property type  Other  Townhouse
# neighbourhood
# Back Bay           2          0
# Dorchester         0          3
# Fenway             0          0
# Jamaica Plain      0          8
# South End          2          4

# %%
# We can normalize with the row or column totals with the normalize parameter. This shows percentage of the total

pd.crosstab(
    index=listing2.neighbourhood,
    columns=listing2.property_type,
    colnames=['property type'],  # name the columns index
    normalize='columns'         # normalize by column
)
# Out:
# property type  Apartment  Bed & Breakfast  Condominium  Dorm     House  \
# neighbourhood
# Back Bay        0.234545         0.000000     0.244444   0.0  0.000000
# Dorchester      0.127273         0.250000     0.200000   0.0  0.434343
# Fenway          0.216364         0.083333     0.088889   0.0  0.020202
# Jamaica Plain   0.178182         0.416667     0.222222   0.0  0.484848
# South End       0.243636         0.250000     0.244444   1.0  0.060606
#
# property type      Loft  Other  Townhouse
# neighbourhood
# Back Bay       0.285714    0.5   0.000000
# Dorchester     0.000000    0.0   0.200000
# Fenway         0.000000    0.0   0.000000
# Jamaica Plain  0.285714    0.0   0.533333
# South End      0.428571    0.5   0.266667

# %%
pd.crosstab(
    index=listing2.neighbourhood,
    columns=listing2.property_type,
    colnames=['property type'],  # name the columns index
    normalize='index'  # normalize by row/index
)
# Out:
# property type  Apartment  Bed & Breakfast  Condominium      Dorm     House  \
# neighbourhood
# Back Bay        0.895833         0.000000     0.076389  0.000000  0.000000
# Dorchester      0.546875         0.023438     0.070312  0.000000  0.335938
# Fenway          0.944444         0.007937     0.031746  0.000000  0.015873
# Jamaica Plain   0.573099         0.029240     0.058480  0.000000  0.280702
# South End       0.817073         0.018293     0.067073  0.006098  0.036585
#
# property type      Loft     Other  Townhouse
# neighbourhood
# Back Bay       0.013889  0.013889   0.000000
# Dorchester     0.000000  0.000000   0.023438
# Fenway         0.000000  0.000000   0.000000
# Jamaica Plain  0.011696  0.000000   0.046784
# South End      0.018293  0.012195   0.024390

# %% [markdown]
# ##  Working with date
# extract year, month, weekday

# %%
reviews=pd.read_csv('https://raw.githubusercontent.com/Suhong88/AA630_Spring2023/main/airbnb_boston/reviews.csv')

# covert listing_id from int to object

reviews['listing_id']=reviews['listing_id'].astype('object')

# covert date from object to date

reviews['date']=pd.to_datetime(reviews.date)

reviews.head()
# Out:
#   listing_id       id       date  reviewer_id reviewer_name  \
# 0    1178162  4724140 2013-05-21      4298113       Olivier
# 1    1178162  4869189 2013-05-29      6452964     Charlotte
# 2    1178162  5003196 2013-06-06      6449554     Sebastian
# 3    1178162  5150351 2013-06-15      2215611        Marine
# 4    1178162  5171140 2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
# create a column for year, month and weekday

# %%
# show number of review by weekday

# %%
# show number of reviews by year

# %% [markdown]
# # Take home assgnments
#
# ## Please complete the following five questions based on cleaned listing data.
#
# - 1. List top 5 neighbourhood that have the best review scores rating
# - 2. Display number of listing, average review score rating, highest and highest review scores rating by nighbourhood by property type
# - 3. List top 10 amenities that have the highest average review score rating
# - 4. For each of the top 5 amenities with the highest average review scores rating, show the number of listing, average price and average review scores rating by neighbourhood.
# - 5. Which neighbourhood has the best review scores in location? Are listings with higher review scores in location also has the higher price? (hint use corr() function)

# %%
import pandas as pd
import numpy as np

## Load the data for further analysis

#listing=pd.read_csv('airbnb_boston/listings_cleaned.csv')

df=pd.read_csv('https://raw.githubusercontent.com/Suhong88/AA630_Spring2023/main/listings_cleaned.csv')

df.head()
# Out:
#          id                            listing_url  \
# 0  12147973  https://www.airbnb.com/rooms/12147973
# 1   3075044   https://www.airbnb.com/rooms/3075044
# 2      6976      https://www.airbnb.com/rooms/6976
# 3   1436513   https://www.airbnb.com/rooms/1436513
# 4   7651065   https://www.airbnb.com/rooms/7651065
#
#                                             name neighbourhood    city state  \
# 0                     Sunny Bungalow in the City    Roslindale  Boston    MA
# 1              Charming room in pet friendly apt    Roslindale  Boston    MA
# 2               Mexican Folk Art Haven in Boston    Roslindale  Boston    MA
# 3  Spacious Sunny Bedroom Suite in Historic Home    Roslindale  Boston    MA
# 4                            Come Home to Boston    Roslindale  Boston    MA
#
#   zipcode   latitude  longitude host_name  ...  bed_type  \
# 0   02131  42.282619 -71.133068  Virginia  ...  Real Bed
# 1   02131  42.286241 -71.134374    Andrea  ...  Real Bed
# 2   02131  42.292438 -71.135765      Phil  ...  Real Bed
# 3     NaN  42.281106 -71.121021    Meghna  ...  Real Bed
# 4   02131  42.284512 -71.136258     Linda  ...  Real Bed
#
#                                            amenities  price  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...  250.0
# 1  {TV,Internet,"Wireless Internet","Air Conditio...   65.0
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...   65.0
# 3  {TV,Internet,"Wireless Internet","Air Conditio...   75.0
# 4  {Internet,"Wireless Internet","Air Conditionin...   79.0
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0             91.916667                9.431571                   9.258041
# 1             94.000000               10.000000                   9.000000
# 2             98.000000               10.000000                   9.000000
# 3            100.000000               10.000000                  10.000000
# 4             99.000000               10.000000                  10.000000
#
#   review_scores_checkin review_scores_communication  review_scores_location  \
# 0              9.646293                    9.646549                9.414043
# 1             10.000000                   10.000000                9.000000
# 2             10.000000                   10.000000                9.000000
# 3             10.000000                   10.000000               10.000000
# 4             10.000000                   10.000000                9.000000
#
#    review_scores_value
# 0             9.168234
# 1             9.000000
# 2            10.000000
# 3            10.000000
# 4            10.000000
#
# [5 rows x 26 columns]

# %% [markdown]
# # 1. List top 5 neighbourhood that have the best review scores rating

# %% [markdown]
# # 2. Display number of listing, average review score rating, highest and highest review scores rating by nighbourhood by property type

# %% [markdown]
# # 3. List top 10 amenities that have the highest average review score rating

# %% [markdown]
# # 4. For each of the top 5 amenities with the highest average review scores rating, show the number of listing, average price and average review scores rating by neighbourhood.

# %% [markdown]
# # 5. Which neighbourhood has the best review scores in location? Are listings with higher review scores in location also has the higher price? (hint use corr() function)
